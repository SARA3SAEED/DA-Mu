# %% [markdown]
# <a href="https://colab.research.google.com/github/SARA3SAEED/DA-Mu/blob/main/s06_matplotlib_seaborn_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Matplotlib, Seaborn, & Plotly Basics

# %% [markdown]
# ## Today's Outline:
# - Introduction to Data Visualization
# - **Matplotlib Basics**
# - **Seaborn Basics**
# - Optional: Pandas Built-in Data Visualization
# - Optional: Plotly
# - Case-study

# %% [markdown]
# ==========

# %% [markdown]
# ## Introduction to Data Visualization

# %% [markdown]
# - Why Data Viz?
#     - Humans are Visual Creatures
#     - Data Interpretation (Yourself)
#     - Communicating Results (Your Audience)
#     - Data Viz is Spectecular

# %% [markdown]
# #### Importing Libraries

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Why Data Viz?

# %%
import numpy as np
import pandas as pd

data = pd.DataFrame({'Month': ['Jul','Aug', 'Sep', 'Oct', 'Nov', 'Dec'],
                    'Profit': [2.0, 2.1, 2.2, 2.1, 2.3, 2.4]})
data
# Out:
#   Month  Profit
# 0   Jul     2.0
# 1   Aug     2.1
# 2   Sep     2.2
# 3   Oct     2.1
# 4   Nov     2.3
# 5   Dec     2.4

# %%
fig, ax = plt.subplots(1,2)
ax[0].plot(data['Month'], data['Profit'])
ax[1].set_ylim([0,3])
ax[1].plot(data['Month'], data['Profit'])

# %% [markdown]
# ### Visualization Classifications
#
# - **Data Type:**
#     - Numerical Data
#     - Categorical Data
#
# - **Number of Variables:**
#     - Single Variable (Univariate)
#     - Two Variables or More (Bivariate / Multivariate)
#
# - **Purpose:**
#     - Distribution (Histogram)
#     - Correlation (Scatter Plot)
#     - Ranking (Bar Plot)
#     - Classification / Grouping (Dendrogram)
#     - Evolution (Line Plot)
#     - Map (Choropleth)
#
# - **Tools:**
#     - https://www.data-to-viz.com/
#     - https://datavizproject.com/
#     - https://datavizcatalogue.com/

# %% [markdown]
# ### How to Choose the Right Visualization
#
# - **Numerical Data**
#     - Univariate
#         - Histograms
#         - Density Plot
#     - Bivariate / Multivariate
#         - Scatter Plots
#         - Histograms
#         - Boxplots
#         - Line Plots
#         - Density Plots
#         - Area Plots
#         - Violin Plots
# - **Categorical Data**
#     - Univariate
#         - Barplots
#         - Pie Charts
#         - Words Clouds
#     - Bivariate / Multivariate
#         - Barplots
#         - Heatmaps
#         - Treemaps
#         - Dendrograms

# %% [markdown]
# ==========

# %% [markdown]
# ## Pandas Built-in Data Visualization (Optional)

# %% [markdown]
# #### Importing Libraries

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Loading Data

# %%
df = pd.read_csv('data/advertising.csv')
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5    NaN        NaN   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3        NaN    NaN
# 4  180.8    NaN       58.4   17.9

# %% [markdown]
# #### Bar Chart

# %%
df[['TV','Radio','Newspaper']].head(5).plot.bar()

# %% [markdown]
# #### Stacked Bar Chart

# %%
df[['TV','Radio','Newspaper']].head(5).plot.bar(stacked=True)

# %% [markdown]
# #### Histogram

# %%
df['Sales'].plot.hist(bins=30)

# %% [markdown]
# #### Scatter Plot

# %%
df.plot.scatter(x='TV',y='Radio')

# %% [markdown]
# #### Boxplot

# %%
df[['TV','Radio','Newspaper']].plot.box()

# %% [markdown]
# ==========

# %% [markdown]
# ## Plotly (Optional)

# %% [markdown]
# - Resources:
#     - Website: https://plot.ly/
#     - API Reference: https://plotly.com/python-api-reference/

# %% [markdown]
# #### Line Plot

# %%
import plotly.express as px
df = px.data.gapminder().query("continent == 'Oceania'")
fig = px.line(df, x='year', y='lifeExp', color='country')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #### Scatter Plot

# %%
# x and y given as DataFrame columns
import plotly.express as px
df = px.data.iris() # iris is a pandas DataFrame
fig = px.scatter(df, x="sepal_width", y="sepal_length")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #### Bubble Chart

# %%
import plotly.express as px
df = px.data.gapminder()

fig = px.scatter(df.query("year==2007"), x="gdpPercap", y="lifeExp",
                size="pop", color="continent",
                 hover_name="country", log_x=True, size_max=60)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #### Bar Chart

# %%
import plotly.express as px
data = px.data.gapminder()
data_canada = data[data.country == 'Canada']
fig = px.bar(data_canada, x='year', y='pop',
             hover_data=['lifeExp', 'gdpPercap'], color='lifeExp',
             labels={'pop':'population of Canada'}, height=400)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #### Stacked Bar Chart

# %%
import plotly.express as px
long_df = px.data.medals_long()
fig = px.bar(long_df, x="nation", y="count", color="medal", title="Long-Form Input")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #### Box Plot

# %%
import plotly.express as px
df = px.data.tips()
fig = px.box(df, x="day", y="total_bill", color="smoker")
fig.update_traces(quartilemethod="exclusive") # or "inclusive", or "linear" by default
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #### Histogram

# %%
import plotly.express as px
df = px.data.tips()
fig = px.histogram(df, x="total_bill")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #### 3D Surface Plot

# %%
import plotly.graph_objects as go
import pandas as pd
import numpy as np
# Read data from a csv
z_data = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/api_docs/mt_bruno_elevation.csv')
z = z_data.values
sh_0, sh_1 = z.shape
x, y = np.linspace(0, 1, sh_0), np.linspace(0, 1, sh_1)
fig = go.Figure(data=[go.Surface(z=z, x=x, y=y)])
fig.update_layout(title='Mt Bruno Elevation', autosize=False,
                  width=500, height=500,
                  margin=dict(l=65, r=50, b=65, t=90))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #### Choropleth Maps

# %%
import plotly.express as px
df = px.data.gapminder().query("year==2007")
fig = px.choropleth(df, locations="iso_alpha",
                    color="lifeExp", # lifeExp is a column of gapminder
                    hover_name="country", # column to add to hover information
                    color_continuous_scale=px.colors.sequential.Plasma)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ==========

# %% [markdown]
# ## Matplotlib Basics

# %% [markdown]
# - Resources:
#     - Documentation: https://matplotlib.org/api/index.html
#     - Cheat Sheet: https://s3.amazonaws.com/assets.datacamp.com/blog_assets/Python_Matplotlib_Cheat_Sheet.pdf
#     - Tutorial: https://github.com/rougier/matplotlib-tutorial

# %% [markdown]
# We have two styles of plotting in matplotlib:
# - **MATLAB-style**
# - **Object-syntax**

# %%
from IPython.display import Image
Image("data/matplotlib-anatomy.png")

# %% [markdown]
# ### Importing Libraries

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Creating Data

# %%
days = ['Mon','Tue','Wed','Thu','Fri','Sat','Sun']
temp_cairo = [22.5, 22.7, 25, 27.3, 26.1, 22.4, 20]
temp_asyut = [30.2, 29, 25, 33.3, 39.7, 35, 28]

# %%
df_cairo = pd.DataFrame(data = {'Day': days, 'Temperatures': temp_cairo})
df_cairo
# Out:
#    Day  Temperatures
# 0  Mon          22.5
# 1  Tue          22.7
# 2  Wed          25.0
# 3  Thu          27.3
# 4  Fri          26.1
# 5  Sat          22.4
# 6  Sun          20.0

# %%
df_asyut = pd.DataFrame(data = {'Day': days, 'Temperatures': temp_asyut})
df_cairo
# Out:
#    Day  Temperatures
# 0  Mon          22.5
# 1  Tue          22.7
# 2  Wed          25.0
# 3  Thu          27.3
# 4  Fri          26.1
# 5  Sat          22.4
# 6  Sun          20.0

# %% [markdown]
# ### Plotting Data (MATLAB-Style)

# %% [markdown]
# #### Line Plot

# %%
plt.plot(df_cairo['Day'], df_cairo['Temperatures'])
plt.show()

# %% [markdown]
# #### Scatter Plot

# %%
plt.scatter(df_cairo['Day'], df_cairo['Temperatures'])
plt.show()

# %% [markdown]
# #### Bar Charts

# %%
plt.bar(df_asyut['Day'], df_asyut['Temperatures'])
plt.show()

# %% [markdown]
# #### Histogram

# %%
my_data = [0,0.6,1.4,1.6,2.2,2.5,2.6,3.2,3.5,3.9,4.2,6]
plt.hist(my_data, bins = 5)
plt.show()

# %% [markdown]
# ### Customizing Plots

# %%
plt.plot(df_cairo['Day'], df_cairo['Temperatures'], label = 'Cairo', color="#FF8C00", ls = '--',
         marker = 's', markeredgecolor="green", markerfacecolor="red", markersize=4)

plt.plot(df_asyut['Day'], df_asyut['Temperatures'], label = 'Asyut', c = 'r', alpha = 0.4, linewidth=2.00)

# x-axis & y-axis
plt.xlabel('Days of the Week')
plt.ylabel('Temperatures in Cel.')

# title
plt.title('Temperatures Degrees in Cairo')

# set the y-limits of the current axes.
plt.ylim(0,100)

# plot titles
plt.legend(loc=0)

plt.show()

# %%
# Saving the figure as an image file
plt.savefig("data/temp.png")

# %% [markdown]
# ### Subplots (Object-Syntax)

# %%
figure, axes = plt.subplots(1, 2, figsize = (10,5))

axes[0].plot(df_asyut['Day'], df_asyut['Temperatures'], c = 'r')
axes[0].set_title('Temperatures Degrees in Asyut')

axes[1].plot(df_cairo['Day'], df_cairo['Temperatures'], c = 'k')
axes[1].set_title('Temperatures Degrees in Cairo')

plt.savefig('temp.png')

plt.show()

# %%
import numpy as np
x = np.linspace(0, 5, 11)
y = x ** 2

# %%
# Create Figure (empty canvas)
fig = plt.figure()

# Add set of axes to figure
axes = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # left, bottom, width, height (range 0 to 1)

# Plot on that set of axes
axes.plot(x, y, 'b')
axes.set_xlabel('Set X Label') # Notice the use of set_ to begin methods
axes.set_ylabel('Set y Label')
axes.set_title('Set Title')
# Out:
# Text(0.5, 1.0, 'Set Title')

# %%
# Creates blank canvas
fig = plt.figure()

axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # main axes
axes2 = fig.add_axes([0.2, 0.5, 0.4, 0.3]) # inset axes

# Larger Figure Axes 1
axes1.plot(x, y, 'b')
axes1.set_xlabel('X_label_axes2')
axes1.set_ylabel('Y_label_axes2')
axes1.set_title('Axes 2 Title')

# Insert Figure Axes 2
axes2.plot(y, x, 'r')
axes2.set_xlabel('X_label_axes2')
axes2.set_ylabel('Y_label_axes2')
axes2.set_title('Axes 2 Title');

# %%
# We can iterate and plot values
fig, axes = plt.subplots(nrows=1, ncols=2)

for ax in axes:
    ax.plot(x, y, 'g')
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_title('title')

fig
plt.tight_layout()

# %% [markdown]
# ==========

# %% [markdown]
# ## Seaborn Basics
# - Distribution Plots
# - Categorical Plots
# - Matrix Plots
# - Regression Plots
# - Styles & Colors

# %% [markdown]
# - Resources
#     - Documentation: https://seaborn.pydata.org/api.html
#     - Gallery: https://seaborn.pydata.org/examples/index.html

# %% [markdown]
# ### Importing Libraries

# %%
import seaborn as sns
sns.set()
# %matplotlib inline

# %% [markdown]
# #### Loading Data

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Distribution Plots

# %% [markdown]
# #### distplot
# The distplot shows the distribution of a univariate set of observations.

# %%
sns.distplot(tips['total_bill'], kde=False, bins=20)

# %% [markdown]
# #### jointplot
# jointplot() allows you to basically match up two distplots for bivariate data. With your choice of what **kind** parameter to compare with:
# * “scatter”
# * “reg”
# * “resid”
# * “kde”
# * “hex”

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='scatter')

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='hex')

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='reg')

# %% [markdown]
# #### pairplot

# %%
sns.pairplot(tips,hue='sex',palette='coolwarm')

# %% [markdown]
# ### Categorical Plots

# %% [markdown]
# #### barplot
# It is a general plot that allows you to aggregate the categorical data based off some function, by default the mean:

# %%
sns.barplot(x='sex',y='total_bill',data=tips,estimator=np.std)

# %% [markdown]
# #### countplot
# This is essentially the same as barplot except the estimator is explicitly counting the number of occurrences. Which is why we only pass the x value:

# %%
sns.countplot(x='sex',data=tips)

# %% [markdown]
# #### boxplot
# A box plot (or box-and-whisker plot) shows the distribution of quantitative data in a way that facilitates comparisons between variables or across levels of a categorical variable.

# %%
sns.boxplot(x="day", y="total_bill", data=tips,palette='rainbow')

# %%
sns.boxplot(x="day", y="total_bill", hue="smoker",data=tips, palette="coolwarm")

# %% [markdown]
# #### violinplot
# It shows the distribution of quantitative data across several levels of one (or more) categorical variables such that those distributions can be compared. Unlike a box plot, in which all of the plot components correspond to actual datapoints, the violin plot features a kernel density estimation of the underlying distribution.

# %%
sns.violinplot(x="day", y="total_bill", data=tips,palette='rainbow')

# %%
sns.violinplot(x="day", y="total_bill", data=tips,hue='sex',palette='Set1')

# %% [markdown]
# ### Matrix Plots

# %% [markdown]
# #### heatmaps
# In order for a heatmap to work properly, your data should already be in a matrix form, the sns.heatmap function basically just colors it in for you.

# %%
# Matrix form for correlation data
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tips.corr(),cmap='coolwarm',annot=True)

# %% [markdown]
# #### Loading Data

# %%
flights = sns.load_dataset('flights')

# %%
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
pvflights = flights.pivot_table(values='passengers',index='month',columns='year')
pvflights
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January     112   115   145   171   196   204   242   284   315   340   360
# February    118   126   150   180   196   188   233   277   301   318   342
# March       132   141   178   193   236   235   267   317   356   362   406
# April       129   135   163   181   235   227   269   313   348   348   396
# May         121   125   172   183   229   234   270   318   355   363   420
# June        135   149   178   218   243   264   315   374   422   435   472
# July        148   170   199   230   264   302   364   413   465   491   548
# August      148   170   199   242   272   293   347   405   467   505   559
# September   136   158   184   209   237   259   312   355   404   404   463
# October     119   133   162   191   211   229   274   306   347   359   407
# November    104   114   146   172   180   203   237   271   305   310   362
# ...

# %%
sns.heatmap(pvflights,cmap='magma',linecolor='white',linewidths=1)

# %% [markdown]
# #### clustermap
# The clustermap uses hierarchal clustering to produce a clustered version of the heatmap.

# %%
sns.clustermap(pvflights,cmap='coolwarm',standard_scale=1)

# %% [markdown]
# ### Regression Plots

# %% [markdown]
# #### lmplot()

# %%
sns.lmplot(x='total_bill',y='tip',data=tips)

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',palette='coolwarm')

# %%
# Working with Markers
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',palette='coolwarm',
           markers=['o','v'],scatter_kws={'s':100})

# %% [markdown]
# ### Styles & Colors

# %% [markdown]
# #### Styles

# %%
sns.set_style('white')

sns.countplot(x='sex',data=tips)

sns.despine(left=True)

# %% [markdown]
# #### Height & Aspect

# %%
# Grid Type Plot
sns.lmplot(x='total_bill',y='tip',height=2,aspect=4,data=tips)

# %% [markdown]
# #### Grids

# %%
# Then you map to the grid
g = sns.PairGrid(tips)
g.map(plt.scatter)

# %%
g = sns.FacetGrid(tips, col="time",  row="smoker")
g = g.map(plt.hist, "total_bill")

# %% [markdown]
# ==========

# %% [markdown]
# ## Case-study: Titanic EDA & Visualization

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %% [markdown]
# ### Loading Data

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# ### EDA & Visualization

# %%
titanic.isnull()
# Out:
#      survived  pclass    sex    age  sibsp  parch   fare  embarked  class  \
# 0       False   False  False  False  False  False  False     False  False
# 1       False   False  False  False  False  False  False     False  False
# 2       False   False  False  False  False  False  False     False  False
# 3       False   False  False  False  False  False  False     False  False
# 4       False   False  False  False  False  False  False     False  False
# ..        ...     ...    ...    ...    ...    ...    ...       ...    ...
# 886     False   False  False  False  False  False  False     False  False
# 887     False   False  False  False  False  False  False     False  False
# 888     False   False  False   True  False  False  False     False  False
# 889     False   False  False  False  False  False  False     False  False
# 890     False   False  False  False  False  False  False     False  False
#
#        who  adult_male   deck  embark_town  alive  alone
# ...

# %%
sns.heatmap(titanic.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
sns.set_style('whitegrid')
sns.countplot(x='survived',data=titanic,palette='RdBu_r')

# %%
sns.set_style('whitegrid')
sns.countplot(x='survived',hue='class',data=titanic,palette='rainbow')

# %%
sns.distplot(titanic['age'].dropna(),kde=False,color='darkred',bins=30)

# %%
sns.countplot(x='sibsp',data=titanic)

# %%
titanic['fare'].hist(color='green',bins=40,figsize=(8,4))

# %% [markdown]
# ==========

# %% [markdown]
# # THANK YOU!
